# %% [markdown]
# # Tri 2 Final Blog
# > Blog about my results in the MCQ #3 Final

# %% [markdown]
# ## Results
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Q5 Benefits of Upgraded System
# ![image.png](attachment:image-2.png)
# ![image.png](attachment:image.png)
# The answer asked for the least, but I didn't see it and chose the most likely benefit instead.

# %% [markdown]
# ### Q40 Moving Robot back to starting place
# ![image.png](attachment:image.png)
# For this one, I did not consider that the robot's perspective of left and right will be switched. I should've think about this more carefully

# %% [markdown]
# ## Summary
# Both of these were careless mistakes that were made sinces I was too fast. Next time, I will take my time to look over the questions and double check my results.
